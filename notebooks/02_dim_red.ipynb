# %% [markdown]
# # Dimensionality Reduction – Heart Disease Dataset
# *PCA, t-SNE, UMAP - Risk Prediction project*
#
# ---
#
# ## Table of Contents

# %% [markdown]
# <a id='imports'></a>
# ## Reproducibility & Imports

# %%
# Reproducibility
import os, sys, umap, numpy as np
import pandas as pd
import joblib

# Imports
sys.path.append(os.path.abspath(os.path.join('..')))
sys.path.append(os.path.abspath(os.path.join('..', 'scripts')))

# Tools
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from scripts.dim_red.plots import plot_cumulative_variance, plot, plot_3d
from imblearn.combine import SMOTEENN

SEED = 42

# %%
df_prep_bal = joblib.load("../outputs/eda/df_preprocessed_balanced.pkl")
df_prep_bal
# Out:
#           age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    0.163636        1                  4.394449         0           0.299065
# 1    0.454545        1                  3.970292         0           0.205607
# 2    0.236364        0                  4.158883         1           0.859813
# 3    0.181818        1                  5.075174         1           0.299065
# 4    0.363636        0                  7.155591         1           0.299065
# ..        ...      ...                       ...       ...                ...
# 303  0.101174        0                  6.368187         0           0.075979
# 304  0.272727        0                  7.155591         0           0.259096
# 305  0.435440        0                  6.989670         0           0.448598
# 306  0.823189        1                  5.006494         0           0.490314
# 307  0.454545        1                  4.947025         1           0.225501
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  12.964542          0.387744      0.565217    0
# 1                      1  12.528160          0.576119      0.521739    0
# 2                      0  12.815841          0.245737      0.434783    1
# 3                      0  12.618186          0.516206      0.565217    0
# 4                      0  12.628070          1.000000      0.521739    1
# ..                   ...        ...               ...           ...  ...
# 303                    0  12.010541          0.227812      0.121322    0
# 304                    0  12.618436          0.453505      0.546076    1
# 305                    0  12.481274          0.453505      0.447133    1
# 306                    0  12.505770          0.344733      0.638942    0
# 307                    0  12.639363          0.843156      0.290031    0
#
#      smoking      time  DEATH_EVENT
# 0          0  0.028470            0
# 1          0  0.042705            0
# 2          0  0.064057            0
# 3          0  0.088968            0
# 4          0  0.092527            0
# ..       ...       ...          ...
# 303        0  0.099076            1
# 304        0  0.584392            1
# 305        0  0.138330            1
# 306        0  0.063024            1
# 307        0  0.040132            1
#
# [308 rows x 13 columns]

# %%
# drop target 
df_copy = df_prep_bal.copy()
TARGET_COL = 'DEATH_EVENT'

X = df_copy.drop(columns=[TARGET_COL])
y = df_copy[TARGET_COL]

cols_to_drop = ['high_blood_pressure', 'platelets', 'sex', 'creatinine_phosphokinase', 'anaemia', 'smoking', 'diabetes']
X = X.drop(columns=cols_to_drop)

X.shape
# Out:
# (308, 5)

# %% [markdown]
# ## PCA

# %%
# standarize data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# PCA with all components
pca_full = PCA()
pca_full.fit(X_scaled)

# explained variance
explained_variance = pca_full.explained_variance_ratio_
print("Explained variance ratio:", explained_variance)
print("Total variance retained:", np.sum(explained_variance))
plot_cumulative_variance(explained_variance, show_target=0.95)
# Out:
# Explained variance ratio: [0.33638389 0.2400092  0.17370533 0.13609668 0.1138049 ]
# Total variance retained: 1.0000000000000002

# %% [markdown]
# - The first component explains ~32% of the total variance.
# - The first three components together explain ~72% of the variance.
# - Around 4 to 5 components are needed to reach 95% variance.

# %%
X_pca = pca_full.transform(X_scaled)   # shape (n_samples, n_features)
X_3d = X_pca[:, :3]                    # first 3 principal components

explained_variance = np.round(pca_full.explained_variance_ratio_, 3)
print("Explained variance ratio:", explained_variance)
print("Total variance retained by 3 PCs:", round(explained_variance[:3].sum(), 3))

df_pca = pd.DataFrame(X_3d, columns=["PCA_1", "PCA_2", "PCA_3"])
df_pca["DEATH_EVENT"] = y.values

os.makedirs("../outputs/dim_red", exist_ok=True)
joblib.dump(df_pca, "../outputs/dim_red/df_pca.pkl")
# Out:
# Explained variance ratio: [0.336 0.24  0.174 0.136 0.114]
# Total variance retained by 3 PCs: 0.75
# ['../outputs/dim_red/df_pca.pkl']

# %%
print("\n Variance kept by first 3 PCs:", round(explained_variance[:3].sum(), 3))
plot_3d(X_3d, y, algorithm="PCA", target_name=TARGET_COL)
# Out:
#  Variance kept by first 3 PCs: 0.75

# %% [markdown]
# We can notice that component 1 is here the most important.

# %% [markdown]
# ## t-SNE

# %%
tsne = TSNE(
    n_components=3,
    perplexity=30,
    learning_rate="auto",
    max_iter=1200,
    early_exaggeration=12.0,
    metric="cosine",
    init="pca",
    n_jobs=-1,
    angle=0.5,
    method="barnes_hut"
)

X_tsne = tsne.fit_transform(X)

df_tsne = pd.DataFrame(X_tsne, columns=["tSNE_1", "tSNE_2", "tSNE_3"])
df_tsne["DEATH_EVENT"] = y.values

os.makedirs("../outputs/dim_red", exist_ok=True)
joblib.dump(df_tsne, "../outputs/dim_red/df_tsne.pkl")
# Out:
# ['../outputs/dim_red/df_tsne.pkl']

# %%
plot_3d(X_tsne, y, algorithm="t-SNE", target_name=TARGET_COL)

# %% [markdown]
# ## UMAP

# %%
reducer = umap.UMAP(
    n_components=3,
    n_neighbors=15,      # controls local/global structure balance
    min_dist=0.05,       # controls cluster compactness
    metric="cosine",
    n_jobs=-1
)

X_umap = reducer.fit_transform(X)

df_umap = pd.DataFrame(X_umap, columns=["UMAP_1", "UMAP_2", "UMAP_3"])
df_umap["DEATH_EVENT"] = y.values

os.makedirs("../outputs/dim_red", exist_ok=True)
joblib.dump(df_umap, "../outputs/dim_red/df_umap.pkl")
# Out:
# ['../outputs/dim_red/df_umap.pkl']

# %%
plot_3d(X_umap, y, algorithm="UMAP", target_name=TARGET_COL)

# %% [markdown]
# ## MIX
# 1st component PCA, t-SNE, UMAP

# %%
pc1 = X_pca[:, 0]
tsne1 = X_tsne[:, 0]
umap1 = X_umap[:, 0]

X_combined = pd.DataFrame({
    "PCA_1": pc1,
    "tSNE_1": tsne1,
    "UMAP_1": umap1,
})

df_mix = pd.concat(
    [pd.DataFrame(X_combined, columns=X_combined.columns),
     pd.Series(y, name='DEATH_EVENT')],
    axis=1
)

os.makedirs("../outputs/dim_red", exist_ok=True)
joblib.dump(df_mix, "../outputs/dim_red/df_mix.pkl")
# Out:
# ['../outputs/dim_red/df_mix.pkl']

# %%
plot_3d(X_combined, y, algorithm="Mix for the 1st component", target_name=TARGET_COL)
